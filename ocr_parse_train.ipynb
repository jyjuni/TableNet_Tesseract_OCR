# %%
import tensorflow as tf
from tensorflow.keras.utils import plot_model
import matplotlib.pyplot as plt
import pydot
import graphviz
from script.network import TableNet

# %% [markdown]
# Paper: https://arxiv.org/abs/2001.01469

# %% [markdown]
# ### Parse Data

# %%
import os
import cv2
import json
import parse
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
from pdf2image import convert_from_path

directory = './dataset/Fintabnet_data/input/'
final_col_directory = './dataset/Fintabnet_data/column_mask/'
final_table_directory = './dataset/Fintabnet_data/table_mask/'
final_cell_directory = './dataset/Fintabnet_data/cell_mask/'
max_tables = 0

df = pd.read_csv("dataset/Fintabnet_data/GT.csv", encoding='utf-8')
ant = df.iloc[:,3]
oss = df.iloc[:,0]
format_string = "http://education-annotate.oss-cn-beijing.aliyuncs.com/table_2%2Fpdf2000%2F{}.pdf"

# %%
for i in range(len(ant)):
	y = json.loads(ant[i])

	# Find all the non-empty annotation records
	if y:
		parsed = parse.parse(format_string, oss[i].split("?")[0])
		filename = parsed[0]

		# Parse width, height
		width = y['container']["page1"]["width"]
		height = y['container']["page1"]["height"]
		
		# convert pdf to image
		page = convert_from_path(f'{directory}{filename}.pdf', size=(width*5, height*5))[0]
		# plt.imshow(page)
		# Create grayscale image array
		col_mask = np.zeros((height, width), dtype=np.int32)
		table_mask = np.zeros((height, width), dtype = np.int32)
		cell_mask = np.zeros((height, width), dtype = np.int32)

		valid = False
		if any("result" not in d for d in y["annotations"]):
			print(f"\033[1;92m ERROR: {filename} no result\033[0m")
			continue
		n_cols = sum(d["result"]["类型"]=="表头" for d in y["annotations"])
		n_tables = sum(d["result"]["类型"]=="表格" for d in y["annotations"])
		print(f"{filename}:{n_cols} columns, {n_tables} tables")
		if not n_cols:
			# n_cols = count_cols(y["annotations"])
			n_cols = 2
			print(f"\033[1;93m WARNING: {filename} no header\033[0m")
		col_x_mins, col_x_maxs = [height] * n_cols, [0] * n_cols
		col_y_mins, col_y_maxs = [width] * n_cols, [0] * n_cols

		# y
		# the result is a Python dictionary:
		for i, d in enumerate(y["annotations"]):
			x_min = int(min(corner[0] for corner in d["points"]))
			x_max = int(max(corner[0] for corner in d["points"]))
			y_min = int(min(corner[1] for corner in d["points"]))
			y_max = int(max(corner[1] for corner in d["points"]))

			if d["result"]["类型"]=="无效数据":
				print(f"{filename} is invalid")
				break
			elif d["result"]["类型"]=="表格": 
				# fill column mask
				for ci in range(n_cols):
					col_mask[col_y_mins[ci]:col_y_maxs[ci], col_x_mins[ci]:col_x_maxs[ci]] = 255

				# fill table mask
				table_mask[y_min:y_max, x_min:x_max] = 255

				# export cropped table image
				table_image = page.crop((d["points"][0][0]*5, d["points"][0][1]*5, d["points"][2][0]*5, d["points"][2][1]*5))
				table_file_name = directory + f"ocr_input/{filename}"
				table_image.save(f"{table_file_name}.png")

				# # export whole table ocr GT
				# generate_table_text(y, i)
				

				# clear col_ arrays
				col_x_mins, col_x_maxs = [height] * n_cols, [0] * n_cols
				col_y_mins, col_y_maxs = [width] * n_cols, [0] * n_cols

			else:
				valid = True
				# fill cell mask
				cell_mask[y_min:y_max, x_min:x_max] = 255
				# plt.imshow(page.crop((x_min*5, y_min*5, x_max*5, y_max*5)))
				# plt.title(d["label"])
				# if len(d["label"].splitlines())>1:
				#     continue
				cell_file_name = f"{final_cell_directory}ocr_traindata/{filename}_seg_{i}"

				label = ''.join(d["label"].splitlines())
				with open(f"{cell_file_name}.gt.txt", "w+") as f:
					f.write(label)

				cell_image = page.crop((x_min*5, y_min*5, x_max*5, y_max*5))
				cell_image.save(f"{cell_file_name}.png")
				# write data to txt
				# im = Image.fromarray(col_mask.astype(np.uint8),'L')
				

				col_x_mins[i%n_cols] = min(col_x_mins[i%n_cols], x_min)
				col_x_maxs[i%n_cols] = max(col_x_maxs[i%n_cols], x_max)
				col_y_mins[i%n_cols] = min(col_y_mins[i%n_cols], y_min)
				col_y_maxs[i%n_cols] = max(col_y_maxs[i%n_cols], y_max)

		if valid:
			im = Image.fromarray(col_mask.astype(np.uint8),'L')
			im.save(final_col_directory + filename + ".jpeg")
			# plt.show(im)

			im = Image.fromarray(table_mask.astype(np.uint8),'L')
			im.save(final_table_directory + filename + ".jpeg")

			im = Image.fromarray(cell_mask.astype(np.uint8),'L')
			im.save(final_cell_directory + filename + ".jpeg")
# Out:
# file0:2 columns, 1 tables
# file1:7 columns, 1 tables
# file3:4 columns, 1 tables
# file4:5 columns, 1 tables
# file5:5 columns, 1 tables
# file6:7 columns, 1 tables
# file7:5 columns, 1 tables
# file8:18 columns, 1 tables
# file9:10 columns, 1 tables
# file12:6 columns, 1 tables
# file13:2 columns, 1 tables
# file14:12 columns, 1 tables
# file15:7 columns, 1 tables
# file16:6 columns, 1 tables
# file18:7 columns, 1 tables
# file19:4 columns, 1 tables
# file20:9 columns, 1 tables
# file21:4 columns, 1 tables
# file22:5 columns, 1 tables
# file23:5 columns, 1 tables
# file24:14 columns, 1 tables
# file25:16 columns, 1 tables
# file26:4 columns, 1 tables
# file28:4 columns, 2 tables
# file29:2 columns, 1 tables
# file30:2 columns, 1 tables
# file31:0 columns, 0 tables
#  WARNING: file31 no header
# file31 is invalid
# file32:2 columns, 1 tables
# file33:7 columns, 1 tables
# file35:5 columns, 1 tables
# file36:5 columns, 1 tables
# file37:8 columns, 2 tables
# file38:7 columns, 1 tables
# file39:5 columns, 1 tables
# file40:12 columns, 1 tables
# file41:18 columns, 1 tables
# file42:10 columns, 1 tables
# file46:6 columns, 1 tables
# file47:8 columns, 1 tables
# file48:2 columns, 1 tables
# file49:6 columns, 1 tables
# file50:6 columns, 1 tables
# file54:2 columns, 1 tables
# file55:7 columns, 1 tables
# file56:7 columns, 1 tables
# file57:5 columns, 1 tables
# file58:4 columns, 1 tables
# file59:5 columns, 1 tables
# file60:5 columns, 1 tables
# file61:5 columns, 1 tables
# file62:11 columns, 1 tables
# file63:16 columns, 1 tables
# file64:9 columns, 1 tables
# file66:3 columns, 1 tables
# file67:8 columns, 1 tables
# file68:2 columns, 1 tables
# file69:1 columns, 1 tables
# file70:4 columns, 1 tables
# file71:2 columns, 1 tables
# file72:0 columns, 0 tables
#  WARNING: file72 no header
# file72 is invalid
# file73:0 columns, 0 tables
#  WARNING: file73 no header
# file73 is invalid
# file74:0 columns, 0 tables
#  WARNING: file74 no header
# file74 is invalid
# file75:1 columns, 1 tables
# file76:0 columns, 1 tables
#  WARNING: file76 no header
# file78:4 columns, 1 tables
# file81:6 columns, 1 tables
# file83:9 columns, 1 tables
# file84:13 columns, 1 tables
# file85:4 columns, 1 tables
# file87:4 columns, 1 tables
# file88:12 columns, 2 tables
# file90:6 columns, 1 tables
# file91:4 columns, 1 tables
# file92:8 columns, 1 tables
# file93:5 columns, 1 tables
# file94:5 columns, 1 tables
# file95:6 columns, 1 tables
# file98:6 columns, 1 tables
# file99:4 columns, 1 tables
# file101:8 columns, 1 tables
# file103:4 columns, 1 tables
# file104:7 columns, 1 tables
# file105:8 columns, 2 tables
# file106:13 columns, 2 tables
# file107:3 columns, 1 tables
# file108:7 columns, 0 tables
# file109:8 columns, 2 tables
# file110:3 columns, 1 tables
# file111:2 columns, 1 tables
# file112:4 columns, 1 tables
# file113:1 columns, 1 tables
# file115:7 columns, 1 tables
# file116:9 columns, 1 tables
# file118:6 columns, 1 tables
# file120:8 columns, 1 tables
# file121:5 columns, 1 tables
# file122:0 columns, 0 tables
#  WARNING: file122 no header
# file122 is invalid
# file123:0 columns, 0 tables
#  WARNING: file123 no header
# file123 is invalid
# file124:0 columns, 0 tables
#  WARNING: file124 no header
# file124 is invalid
# file125:0 columns, 0 tables
#  WARNING: file125 no header
# file125 is invalid
# file126:7 columns, 1 tables
# file127:7 columns, 1 tables
# file129:10 columns, 1 tables
# file131:6 columns, 2 tables
# file136:6 columns, 1 tables
# file137:2 columns, 1 tables
# file139:2 columns, 1 tables
# file140:0 columns, 1 tables
#  WARNING: file140 no header
# file141:1 columns, 1 tables
# file144:6 columns, 1 tables
# file147:6 columns, 1 tables
# file148:6 columns, 1 tables
# file150:4 columns, 1 tables
# file151:7 columns, 1 tables
# file152:4 columns, 1 tables
# file153:3 columns, 1 tables
# file155:3 columns, 1 tables
# file180:8 columns, 1 tables
# file181:5 columns, 1 tables
# file182:0 columns, 0 tables
#  WARNING: file182 no header
# file182 is invalid
# file183:0 columns, 0 tables
#  WARNING: file183 no header
# file183 is invalid
# file184:0 columns, 0 tables
#  WARNING: file184 no header
# file184 is invalid
# file185:0 columns, 0 tables
#  WARNING: file185 no header
# file185 is invalid
# file186:10 columns, 2 tables
# file187:1 columns, 1 tables
# file189:10 columns, 2 tables
# file190:5 columns, 1 tables
# file191:6 columns, 1 tables
# file193:4 columns, 1 tables
# file194:6 columns, 1 tables
# file195:6 columns, 1 tables
# file199:12 columns, 2 tables
# file203:5 columns, 1 tables
# file204:8 columns, 1 tables
# file205:11 columns, 1 tables
# file206:3 columns, 1 tables
# file207:5 columns, 1 tables
# file209:5 columns, 1 tables
# file210:10 columns, 2 tables
# file211:9 columns, 1 tables
# file212:13 columns, 1 tables
# file213:4 columns, 1 tables
# file214:10 columns, 2 tables
# file215:8 columns, 1 tables
# file216:12 columns, 2 tables
# file217:1 columns, 1 tables
# file218:10 columns, 1 tables
# file219:4 columns, 1 tables
# file220:5 columns, 2 tables
# file221:8 columns, 1 tables
# file222:4 columns, 1 tables
# file225:5 columns, 1 tables
# file226:0 columns, 0 tables
#  WARNING: file226 no header
# file226 is invalid
# file227:0 columns, 0 tables
#  WARNING: file227 no header
# file227 is invalid
# file228:0 columns, 0 tables
#  WARNING: file228 no header
# file228 is invalid
# file229:0 columns, 0 tables
#  WARNING: file229 no header
# file229 is invalid
# ERROR: file230 no result
# file231:8 columns, 1 tables
# file232:10 columns, 1 tables
# file235:6 columns, 1 tables
# file236:12 columns, 2 tables
# file238:7 columns, 1 tables
# file240:10 columns, 1 tables
# file242:6 columns, 1 tables
# file243:5 columns, 1 tables
# file244:6 columns, 1 tables
# file245:6 columns, 1 tables
# file246:1 columns, 1 tables
# file247:6 columns, 1 tables
# file248:6 columns, 2 tables
# file249:11 columns, 2 tables
# file250:5 columns, 1 tables
# file251:6 columns, 1 tables
# file252:5 columns, 1 tables
# file253:11 columns, 2 tables
# file254:11 columns, 2 tables
# file255:6 columns, 1 tables
# file256:5 columns, 1 tables
# file257:0 columns, 1 tables
#  WARNING: file257 no header
# file258:11 columns, 2 tables
# file259:3 columns, 2 tables
# file260:2 columns, 1 tables
# file261:3 columns, 1 tables
# file262:2 columns, 2 tables
# file264:4 columns, 2 tables
# file265:0 columns, 1 tables
#  WARNING: file265 no header
# file266:0 columns, 1 tables
#  WARNING: file266 no header
# file267:0 columns, 1 tables
#  WARNING: file267 no header
# file268:6 columns, 1 tables
# file269:6 columns, 1 tables
# file271:6 columns, 1 tables
# file272:6 columns, 1 tables
# file275:4 columns, 1 tables
# file276:4 columns, 1 tables
# file277:5 columns, 1 tables
# file278:4 columns, 1 tables
# file279:2 columns, 1 tables
# file280:2 columns, 1 tables
# file281:0 columns, 0 tables
#  WARNING: file281 no header
# file281 is invalid
# file282:0 columns, 0 tables
#  WARNING: file282 no header
# file282 is invalid
# file283:0 columns, 0 tables
#  WARNING: file283 no header
# file283 is invalid
# file284:0 columns, 0 tables
#  WARNING: file284 no header
# file284 is invalid
# file285:1 columns, 1 tables
# file286:0 columns, 1 tables
#  WARNING: file286 no header
# file287:6 columns, 1 tables
# file288:6 columns, 1 tables
# file291:6 columns, 1 tables
# file294:6 columns, 1 tables
# file295:6 columns, 1 tables
# file296:6 columns, 1 tables
# file298:4 columns, 1 tables
# file299:12 columns, 2 tables
# file300:4 columns, 1 tables
# file301:3 columns, 1 tables
# file302:7 columns, 1 tables
# file303:3 columns, 1 tables
# file304:6 columns, 1 tables
# file306:5 columns, 1 tables
# file308:5 columns, 1 tables
# file309:5 columns, 1 tables
# file310:5 columns, 1 tables
# file311:23 columns, 2 tables
# file312:4 columns, 1 tables
# file314:8 columns, 1 tables
# file316:8 columns, 1 tables
# file317:8 columns, 1 tables
# file318:2 columns, 1 tables
# file319:7 columns, 0 tables
# file320:7 columns, 2 tables
# file321:2 columns, 1 tables
# file322:1 columns, 1 tables
# file323:8 columns, 1 tables
# file324:8 columns, 1 tables
# file326:6 columns, 1 tables
# file327:5 columns, 1 tables
# file328:8 columns, 1 tables
# file329:5 columns, 1 tables
# file330:0 columns, 0 tables
#  WARNING: file330 no header
# file330 is invalid
# file331:0 columns, 0 tables
#  WARNING: file331 no header
# file331 is invalid
# file332:0 columns, 0 tables
#  WARNING: file332 no header
# file332 is invalid
# file333:0 columns, 0 tables
#  WARNING: file333 no header
# file333 is invalid
# file335:12 columns, 2 tables
# file336:7 columns, 1 tables
# file337:6 columns, 1 tables
# file338:6 columns, 1 tables
# file339:6 columns, 1 tables
# file340:6 columns, 1 tables
# file341:4 columns, 1 tables
# file342:8 columns, 1 tables
# file343:5 columns, 1 tables
# file344:7 columns, 1 tables
# file345:7 columns, 1 tables
# file346:2 columns, 1 tables
# file347:6 columns, 2 tables
# file348:2 columns, 1 tables
# file349:0 columns, 0 tables
#  WARNING: file349 no header
# file349 is invalid
# file350:0 columns, 0 tables
#  WARNING: file350 no header
# file350 is invalid
# file351:0 columns, 0 tables
#  WARNING: file351 no header
# file351 is invalid
# file352:3 columns, 1 tables
# file353:2 columns, 1 tables
# file354:5 columns, 1 tables
# file355:8 columns, 1 tables
# file357:2 columns, 1 tables
# file358:0 columns, 2 tables
#  WARNING: file358 no header
# file359:3 columns, 1 tables
# file360:0 columns, 1 tables
#  WARNING: file360 no header
# file361:10 columns, 2 tables
# file362:2 columns, 1 tables
# file363:8 columns, 1 tables
# file364:4 columns, 3 tables
# file365:0 columns, 1 tables
#  WARNING: file365 no header
# file366:12 columns, 2 tables
# file367:0 columns, 0 tables
#  WARNING: file367 no header
# file367 is invalid
# file368:0 columns, 0 tables
#  WARNING: file368 no header
# file368 is invalid
# file369:2 columns, 1 tables
# file370:9 columns, 1 tables
# file371:3 columns, 1 tables
# file372:0 columns, 0 tables
#  WARNING: file372 no header
# file372 is invalid
# file373:0 columns, 2 tables
#  WARNING: file373 no header
# file374:4 columns, 1 tables
# file375:4 columns, 1 tables
# file376:3 columns, 1 tables
# file377:8 columns, 1 tables
# file378:2 columns, 1 tables
# file379:0 columns, 1 tables
#  WARNING: file379 no header
# file380:0 columns, 0 tables
#  WARNING: file380 no header
# file380 is invalid
# file381:3 columns, 1 tables
# file382:0 columns, 0 tables
#  WARNING: file382 no header
# file382 is invalid
# file383:0 columns, 2 tables
#  WARNING: file383 no header
# file384:4 columns, 1 tables
# file385:2 columns, 1 tables
# file386:4 columns, 1 tables
# file387:8 columns, 1 tables
# ERROR: file388 no result
# file389:0 columns, 1 tables
#  WARNING: file389 no header
# file390:10 columns, 1 tables
# file391:0 columns, 0 tables
#  WARNING: file391 no header
# file391 is invalid
# file392:3 columns, 1 tables
# file393:2 columns, 1 tables
# file395:10 columns, 1 tables
# file396:0 columns, 0 tables
#  WARNING: file396 no header
# file396 is invalid
# file397:2 columns, 1 tables
# file399:5 columns, 1 tables
# file400:5 columns, 1 tables
# file401:5 columns, 1 tables
# file402:0 columns, 1 tables
#  WARNING: file402 no header
# file403:0 columns, 1 tables
#  WARNING: file403 no header
# file404:0 columns, 1 tables
#  WARNING: file404 no header
# file405:2 columns, 1 tables
# file406:7 columns, 1 tables
# file407:5 columns, 1 tables
# file408:4 columns, 1 tables
# file409:2 columns, 2 tables
# file410:8 columns, 3 tables
# file411:4 columns, 2 tables
# file412:17 columns, 3 tables
# file413:12 columns, 3 tables
# file415:7 columns, 1 tables
# file420:8 columns, 1 tables
# file421:9 columns, 2 tables
# file422:9 columns, 2 tables
# file423:1 columns, 1 tables
# file424:2 columns, 1 tables
# file425:19 columns, 2 tables
# file426:17 columns, 3 tables
# file427:2 columns, 1 tables
# file429:4 columns, 1 tables
# file430:18 columns, 3 tables
# file431:7 columns, 1 tables
# file432:7 columns, 1 tables
# file433:10 columns, 1 tables
# file434:16 columns, 2 tables
# file435:3 columns, 1 tables
# file436:4 columns, 2 tables
# file437:8 columns, 3 tables
# file439:3 columns, 1 tables
# file440:7 columns, 2 tables
# file443:0 columns, 0 tables
#  WARNING: file443 no header
# file443 is invalid
# file444:6 columns, 1 tables
# file445:0 columns, 0 tables
#  WARNING: file445 no header
# file445 is invalid
# file446:0 columns, 0 tables
#  WARNING: file446 no header
# file446 is invalid
# file448:7 columns, 1 tables
# file449:0 columns, 0 tables
#  WARNING: file449 no header
# file449 is invalid
# file450:5 columns, 1 tables
# file451:5 columns, 1 tables
# file452:0 columns, 1 tables
#  WARNING: file452 no header
# file453:0 columns, 1 tables
#  WARNING: file453 no header
# file455:0 columns, 1 tables
#  WARNING: file455 no header
# file456:8 columns, 2 tables
# file457:11 columns, 2 tables
# file458:8 columns, 1 tables
# file459:6 columns, 3 tables
# file460:6 columns, 2 tables
# file461:8 columns, 3 tables
# file462:2 columns, 1 tables
# file463:5 columns, 1 tables
# file464:7 columns, 1 tables
# file465:12 columns, 2 tables
# file466:2 columns, 1 tables
# file467:2 columns, 1 tables

# %%
# # load JSON
# x = ant[2] #img_0
# plt.imshow(page)
# # parse x:
# y = json.loads(x)

# n_cols = sum(d["result"]["类型"]=="表头" for d in y["annotations"])
# col_x_mins, col_x_maxs = [float("inf")] * n_cols, [0] * n_cols
# col_y_mins, col_y_maxs = [float("inf")] * n_cols, [0] * n_cols

# y["annotations"]
# Out:
# 'http://education-annotate.oss-cn-beijing.aliyuncs.com/table_2%2Fpdf2000%2Ffile3.pdf?OSSAccessKeyId=LTAIqzGnw1FYDk8Q&Expires=1672542720&Signature=mQexZwf%2B05s1mDjHY4p09kD456k%3D'

# %%
# !python3 data_preprocess/generate_mask_json.py
# Out:
# file0:2 columns, 1 tables
# file1:7 columns, 1 tables
# file2:4 columns, 1 tables
# file3:5 columns, 1 tables
# file4:5 columns, 1 tables
# file5:7 columns, 1 tables
# file6:5 columns, 1 tables
# file7:18 columns, 1 tables
# file8:10 columns, 1 tables
# file9:6 columns, 1 tables
# file10:2 columns, 1 tables
# file11:12 columns, 1 tables
# file12:7 columns, 1 tables
# file13:6 columns, 1 tables
# file14:7 columns, 1 tables
# file15:4 columns, 1 tables
# file16:9 columns, 1 tables
# file17:4 columns, 1 tables
# file18:5 columns, 1 tables
# file19:5 columns, 1 tables
# file20:14 columns, 1 tables
# file21:16 columns, 1 tables
# file22:4 columns, 1 tables
# file23:4 columns, 2 tables
# file24:2 columns, 1 tables
# file25:2 columns, 1 tables
# file26:0 columns, 0 tables
# WARNING: file26 no header
# file26 is invalid
# file27:2 columns, 1 tables
# file28:7 columns, 1 tables
# file29:5 columns, 1 tables
# file30:5 columns, 1 tables
# file31:8 columns, 2 tables
# file32:7 columns, 1 tables
# file33:5 columns, 1 tables
# file34:12 columns, 1 tables
# file35:18 columns, 1 tables
# file36:10 columns, 1 tables
# file37:6 columns, 1 tables
# file38:8 columns, 1 tables
# file39:2 columns, 1 tables
# file40:6 columns, 1 tables
# file41:6 columns, 1 tables
# file42:2 columns, 1 tables
# file43:7 columns, 1 tables
# file44:7 columns, 1 tables
# file45:5 columns, 1 tables
# file46:4 columns, 1 tables
# file47:5 columns, 1 tables
# file48:5 columns, 1 tables
# file49:5 columns, 1 tables
# file50:11 columns, 1 tables
# file51:16 columns, 1 tables
# file52:9 columns, 1 tables
# file53:3 columns, 1 tables
# file54:8 columns, 1 tables
# file55:2 columns, 1 tables
# file56:1 columns, 1 tables
# file57:4 columns, 1 tables
# file58:2 columns, 1 tables
# file59:0 columns, 0 tables
# WARNING: file59 no header
# file59 is invalid
# file60:0 columns, 0 tables
# WARNING: file60 no header
# file60 is invalid
# file61:0 columns, 0 tables
# WARNING: file61 no header
# file61 is invalid
# file62:1 columns, 1 tables
# file63:0 columns, 1 tables
# WARNING: file63 no header
# file64:4 columns, 1 tables
# file65:6 columns, 1 tables
# file66:9 columns, 1 tables
# file67:13 columns, 1 tables
# file68:4 columns, 1 tables
# file69:4 columns, 1 tables
# file70:12 columns, 2 tables
# file71:6 columns, 1 tables
# file72:4 columns, 1 tables
# file73:8 columns, 1 tables
# file74:5 columns, 1 tables
# file75:5 columns, 1 tables
# file76:6 columns, 1 tables
# file77:6 columns, 1 tables
# file78:4 columns, 1 tables
# file79:8 columns, 1 tables
# file80:4 columns, 1 tables
# file81:7 columns, 1 tables
# file82:8 columns, 2 tables
# file83:13 columns, 2 tables
# file84:3 columns, 1 tables
# file85:7 columns, 0 tables
# file86:8 columns, 2 tables
# file87:3 columns, 1 tables
# file88:2 columns, 1 tables
# file89:4 columns, 1 tables
# file90:1 columns, 1 tables
# file91:7 columns, 1 tables
# file92:9 columns, 1 tables
# file93:6 columns, 1 tables
# file94:8 columns, 1 tables
# file95:5 columns, 1 tables
# file96:0 columns, 0 tables
# WARNING: file96 no header
# file96 is invalid
# file97:0 columns, 0 tables
# WARNING: file97 no header
# file97 is invalid
# file98:0 columns, 0 tables
# WARNING: file98 no header
# file98 is invalid
# file99:0 columns, 0 tables
# WARNING: file99 no header
# file99 is invalid
# file100:7 columns, 1 tables
# file101:7 columns, 1 tables
# file102:10 columns, 1 tables
# file103:6 columns, 2 tables
# file104:6 columns, 1 tables
# file105:2 columns, 1 tables
# file106:2 columns, 1 tables
# file107:0 columns, 1 tables
# WARNING: file107 no header
# file108:1 columns, 1 tables
# file109:6 columns, 1 tables
# file110:6 columns, 1 tables
# file111:6 columns, 1 tables
# file112:4 columns, 1 tables
# file113:7 columns, 1 tables
# file114:4 columns, 1 tables
# file115:3 columns, 1 tables
# file116:3 columns, 1 tables
# file117:8 columns, 1 tables
# file118:5 columns, 1 tables
# file119:0 columns, 0 tables
# WARNING: file119 no header
# file119 is invalid
# file120:0 columns, 0 tables
# WARNING: file120 no header
# file120 is invalid
# file121:0 columns, 0 tables
# WARNING: file121 no header
# file121 is invalid
# file122:0 columns, 0 tables
# WARNING: file122 no header
# file122 is invalid
# file123:10 columns, 2 tables
# file124:1 columns, 1 tables
# file125:10 columns, 2 tables
# file126:5 columns, 1 tables
# file127:6 columns, 1 tables
# file128:4 columns, 1 tables
# file129:6 columns, 1 tables
# file130:6 columns, 1 tables
# file131:12 columns, 2 tables
# file132:5 columns, 1 tables
# file133:8 columns, 1 tables
# file134:11 columns, 1 tables
# file135:3 columns, 1 tables
# file136:5 columns, 1 tables
# file137:5 columns, 1 tables
# file138:10 columns, 2 tables
# file139:9 columns, 1 tables
# file140:13 columns, 1 tables
# file141:4 columns, 1 tables
# file142:10 columns, 2 tables
# file143:8 columns, 1 tables
# file144:12 columns, 2 tables
# file145:1 columns, 1 tables
# file146:10 columns, 1 tables
# file147:4 columns, 1 tables
# file148:5 columns, 2 tables
# file149:8 columns, 1 tables
# file150:4 columns, 1 tables
# file151:5 columns, 1 tables
# file152:0 columns, 0 tables
# WARNING: file152 no header
# file152 is invalid
# file153:0 columns, 0 tables
# WARNING: file153 no header
# file153 is invalid
# file154:0 columns, 0 tables
# WARNING: file154 no header
# file154 is invalid
# file155:0 columns, 0 tables
# WARNING: file155 no header
# file155 is invalid
# ERROR: file156 no result
# file157:8 columns, 1 tables
# file158:10 columns, 1 tables
# file159:6 columns, 1 tables
# file160:12 columns, 2 tables
# file161:7 columns, 1 tables
# file162:10 columns, 1 tables
# file163:6 columns, 1 tables
# file164:5 columns, 1 tables
# file165:6 columns, 1 tables
# file166:6 columns, 1 tables
# file167:1 columns, 1 tables
# file168:6 columns, 1 tables
# file169:6 columns, 2 tables
# file170:11 columns, 2 tables
# file171:5 columns, 1 tables
# file172:6 columns, 1 tables
# file173:5 columns, 1 tables
# file174:11 columns, 2 tables
# file175:11 columns, 2 tables
# file176:6 columns, 1 tables
# file177:5 columns, 1 tables
# file178:0 columns, 1 tables
# WARNING: file178 no header
# file179:11 columns, 2 tables
# file180:3 columns, 2 tables
# file181:2 columns, 1 tables
# file182:3 columns, 1 tables
# file183:2 columns, 2 tables
# file184:4 columns, 2 tables
# file185:0 columns, 1 tables
# WARNING: file185 no header
# file186:0 columns, 1 tables
# WARNING: file186 no header
# file187:0 columns, 1 tables
# WARNING: file187 no header
# file188:6 columns, 1 tables
# file189:6 columns, 1 tables
# file190:6 columns, 1 tables
# file191:6 columns, 1 tables
# file192:4 columns, 1 tables
# file193:4 columns, 1 tables
# file194:5 columns, 1 tables
# file195:4 columns, 1 tables
# file196:2 columns, 1 tables
# file197:2 columns, 1 tables
# file198:0 columns, 0 tables
# WARNING: file198 no header
# file198 is invalid
# file199:0 columns, 0 tables
# WARNING: file199 no header
# file199 is invalid
# file200:0 columns, 0 tables
# WARNING: file200 no header
# file200 is invalid
# file201:0 columns, 0 tables
# WARNING: file201 no header
# file201 is invalid
# file202:1 columns, 1 tables
# file203:0 columns, 1 tables
# WARNING: file203 no header
# file204:6 columns, 1 tables
# file205:6 columns, 1 tables
# file206:6 columns, 1 tables
# file207:6 columns, 1 tables
# file208:6 columns, 1 tables
# file209:6 columns, 1 tables
# file210:4 columns, 1 tables
# file211:12 columns, 2 tables
# file212:4 columns, 1 tables
# file213:3 columns, 1 tables
# file214:7 columns, 1 tables
# file215:3 columns, 1 tables
# file216:6 columns, 1 tables
# file217:5 columns, 1 tables
# file218:5 columns, 1 tables
# file219:5 columns, 1 tables
# file220:5 columns, 1 tables
# file221:23 columns, 2 tables
# file222:4 columns, 1 tables
# file223:8 columns, 1 tables
# file224:8 columns, 1 tables
# file225:8 columns, 1 tables
# file226:2 columns, 1 tables
# file227:7 columns, 0 tables
# file228:7 columns, 2 tables
# file229:2 columns, 1 tables
# file230:1 columns, 1 tables
# file231:8 columns, 1 tables
# file232:8 columns, 1 tables
# file233:6 columns, 1 tables
# file234:5 columns, 1 tables
# file235:8 columns, 1 tables
# file236:5 columns, 1 tables
# file237:0 columns, 0 tables
# WARNING: file237 no header
# file237 is invalid
# file238:0 columns, 0 tables
# WARNING: file238 no header
# file238 is invalid
# file239:0 columns, 0 tables
# WARNING: file239 no header
# file239 is invalid
# file240:0 columns, 0 tables
# WARNING: file240 no header
# file240 is invalid
# file241:12 columns, 2 tables
# file242:7 columns, 1 tables
# file243:6 columns, 1 tables
# file244:6 columns, 1 tables
# file245:6 columns, 1 tables
# file246:6 columns, 1 tables
# file247:4 columns, 1 tables
# file248:8 columns, 1 tables
# file249:5 columns, 1 tables
# file250:7 columns, 1 tables
# file251:7 columns, 1 tables
# file252:2 columns, 1 tables
# file253:6 columns, 2 tables
# file254:2 columns, 1 tables
# file255:0 columns, 0 tables
# WARNING: file255 no header
# file255 is invalid
# file256:0 columns, 0 tables
# WARNING: file256 no header
# file256 is invalid
# file257:0 columns, 0 tables
# WARNING: file257 no header
# file257 is invalid
# file258:3 columns, 1 tables
# file259:2 columns, 1 tables
# file260:5 columns, 1 tables
# file261:8 columns, 1 tables
# file262:2 columns, 1 tables
# file263:0 columns, 2 tables
# WARNING: file263 no header
# file264:3 columns, 1 tables
# file265:0 columns, 1 tables
# WARNING: file265 no header
# file266:10 columns, 2 tables
# file267:2 columns, 1 tables
# file268:8 columns, 1 tables
# file269:4 columns, 3 tables
# file270:0 columns, 1 tables
# WARNING: file270 no header
# file271:12 columns, 2 tables
# file272:0 columns, 0 tables
# WARNING: file272 no header
# file272 is invalid
# file273:0 columns, 0 tables
# WARNING: file273 no header
# file273 is invalid
# file274:2 columns, 1 tables
# file275:9 columns, 1 tables
# file276:3 columns, 1 tables
# file277:0 columns, 0 tables
# WARNING: file277 no header
# file277 is invalid
# file278:0 columns, 2 tables
# WARNING: file278 no header
# file279:4 columns, 1 tables
# file280:4 columns, 1 tables
# file281:3 columns, 1 tables
# file282:8 columns, 1 tables
# file283:2 columns, 1 tables
# file284:0 columns, 1 tables
# WARNING: file284 no header
# file285:0 columns, 0 tables
# WARNING: file285 no header
# file285 is invalid
# file286:3 columns, 1 tables
# file287:0 columns, 0 tables
# WARNING: file287 no header
# file287 is invalid
# file288:0 columns, 2 tables
# WARNING: file288 no header
# file289:4 columns, 1 tables
# file290:2 columns, 1 tables
# file291:4 columns, 1 tables
# file292:8 columns, 1 tables
# ERROR: file293 no result
# file294:0 columns, 1 tables
# WARNING: file294 no header
# file295:10 columns, 1 tables
# file296:0 columns, 0 tables
# WARNING: file296 no header
# file296 is invalid
# file297:3 columns, 1 tables
# file298:2 columns, 1 tables
# file299:10 columns, 1 tables
# file300:0 columns, 0 tables
# WARNING: file300 no header
# file300 is invalid
# file301:2 columns, 1 tables
# file302:5 columns, 1 tables
# file303:5 columns, 1 tables
# file304:5 columns, 1 tables
# file305:0 columns, 1 tables
# WARNING: file305 no header
# file306:0 columns, 1 tables
# WARNING: file306 no header
# file307:0 columns, 1 tables
# WARNING: file307 no header
# file308:2 columns, 1 tables
# file309:7 columns, 1 tables
# file310:5 columns, 1 tables
# file311:4 columns, 1 tables
# file312:2 columns, 2 tables
# file313:8 columns, 3 tables
# file314:4 columns, 2 tables
# file315:17 columns, 3 tables
# file316:12 columns, 3 tables
# file317:7 columns, 1 tables
# file318:8 columns, 1 tables
# file319:9 columns, 2 tables
# file320:9 columns, 2 tables
# file321:1 columns, 1 tables
# file322:2 columns, 1 tables
# file323:19 columns, 2 tables
# file324:17 columns, 3 tables
# file325:2 columns, 1 tables
# file326:4 columns, 1 tables
# file327:18 columns, 3 tables
# file328:7 columns, 1 tables
# file329:7 columns, 1 tables
# file330:10 columns, 1 tables
# file331:16 columns, 2 tables
# file332:3 columns, 1 tables
# file333:4 columns, 2 tables
# file334:8 columns, 3 tables
# file335:3 columns, 1 tables
# file336:7 columns, 2 tables
# file337:0 columns, 0 tables
# WARNING: file337 no header
# file337 is invalid
# file338:6 columns, 1 tables
# file339:0 columns, 0 tables
# WARNING: file339 no header
# file339 is invalid
# file340:0 columns, 0 tables
# WARNING: file340 no header
# file340 is invalid
# file341:7 columns, 1 tables
# file342:0 columns, 0 tables
# WARNING: file342 no header
# file342 is invalid
# file343:5 columns, 1 tables
# file344:5 columns, 1 tables
# file345:0 columns, 1 tables
# WARNING: file345 no header
# file346:0 columns, 1 tables
# WARNING: file346 no header
# file347:0 columns, 1 tables
# WARNING: file347 no header
# file348:8 columns, 2 tables
# file349:11 columns, 2 tables
# file350:8 columns, 1 tables
# file351:6 columns, 3 tables
# file352:6 columns, 2 tables
# file353:8 columns, 3 tables
# file354:2 columns, 1 tables
# file355:5 columns, 1 tables
# file356:7 columns, 1 tables
# file357:12 columns, 2 tables
# file358:2 columns, 1 tables
# file359:2 columns, 1 tables

# %%
# for debugging only
from data_preprocess.generate_mask_json import show_sample
show_sample(2)
# Out:
# [{'id': 1,
#   'points': [[42.27272727272728, 260.8264437588779],
#    [101.81818181818183, 260.8264437588779],
#    [101.81818181818183, 271.2809892134233],
#    [42.27272727272728, 271.2809892134233]],
#   'label': 'NSP-Minnesota',
#   'page': 1,
#   'result': {'类型': '表内容'},
#   'color': 'rgba(145, 204, 51, 1)'},
#  {'id':

#   'page': 1,
#   'result': {'类型': '表内容'},
#   'color': 'rgba(145, 204, 51, 1)'},
#  {'id': 105,
#   'points': [[526.3636363636364, 629.2148659446024],
#    [550.4545454545455, 629.2148659446024],
#    [550.4545454545455, 638.3057750355115],
#    [526.3636363636364, 638.3057750355115]],
#   'label': 'BBB+',
#   'page': 1,
#   'result': {'类型': '表内容'},
#   'color': 'rgba(145, 204, 51, 1)'},
#  {'id': 106,
#   'points': [[500.00000000000006, 639.2148659446024],
#    [518.1818181818182, 639.2148659446024],
#    [518.1818181818182, 651.4875932173296],
#    [500.00000000000006, 651.4875932173296]],
#   'label': 'A-2',
#   'page': 1,
#   'result': {'类型': '表内容'},
#   'color': 'rgba(145, 204, 51, 1)'},
#  {'id': 107,
#   'points': [[539.0909090909091, 640.1239568536932],
#    [550.909090909091, 640.1239568536932],
#    [550.909090909091, 651.0330477627841],
#    [539.0909090909091, 651.0330477627841]],
#   'label': 'F2',
#   'page': 1,
#   'result': {'类型': '表内容'},
#   'color': 'rgba(145, 204, 51, 1)'},
#  {'id': 108,
#   'points': [[43.63636363636364, 499.6694113991478],
#    [552.7272727272727, 499.6694113991478],
#    [552.7272727272727, 654.2148659446024],
#    [43.63636363636364, 654.2148659446024]],
#   'label': '',
#   'page': 1,
#   'result': {'类型': '表格'},
#   'color': 'rgba(166, 204, 51, 1)'}]

# %% [markdown]
# ### OCR

# %% [markdown]
# <b>Train OCR With Tesstrain</b>

# %%
# # !mkdir dataset/Fintabnet_data/cell_mask/ocr_traindata
# !mv dataset/Fintabnet_data/cell_mask/*.gt.txt dataset/Fintabnet_data/cell_mask/*.png dataset/Fintabnet_data/cell_mask/ocr_traindata/
# !cp -r dataset/Fintabnet_data/cell_mask/ocr_traindata  ~/eyegaze/tesstrain/data/
# !cd ~/eyegaze/tesstrain/ && make training MODEL_NAME=foo DATA_DIR=data GROUND_TRUTH_DIR=data/ocr_traindata
# Out:
# find -L data/ocr_traindata -name '*.gt.txt' | xargs paste -s > "data/foo/all-gt"
# unicharset_extractor --output_unicharset "data/foo/unicharset" --norm_mode 2 "data/foo/all-gt"
# unicharset_extractor: error while loading shared libraries: libtesseract.so.5: cannot open shared object file: No such file or directory
# make: *** [Makefile:197: data/foo/unicharset] Error 127

# %% [markdown]
# <b>Load Model</b>

# %%
# copy trained model from tesstrain to our project dataset: 
# !sudo cp ~/eyegaze/tesstrain/data/foo.traineddata dataset/foo.traineddata

# add to tesseract langugage models 
# !sudo cp dataset/foo.traineddata /home/linuxbrew/.linuxbrew/share/tessdata/fintabnet.traineddata #REPLACE BY YOUR TESSERACT TESSDATA DIRECTORY

# %% [markdown]
# <b>Predict</b>
#
# See part II.

# %% [markdown]
# <!--
# Page segmentation modes:
#   0    Orientation and script detection (OSD) only.
#   1    Automatic page segmentation with OSD.
#   2    Automatic page segmentation, but no OSD, or OCR.
#   3    Fully automatic page segmentation, but no OSD. (Default)
#   4    Assume a single column of text of variable sizes.
#   5    Assume a single uniform block of vertically aligned text.
#   6    Assume a single uniform block of text.
#   7    Treat the image as a single text line.
#   8    Treat the image as a single word.
#   9    Treat the image as a single word in a circle.
#  10    Treat the image as a single character.
#  11    Sparse text. Find as much text as possible in no particular order.
#  12    Sparse text with OSD.
#  13    Raw line. Treat the image as a single text line,
#                         bypassing hacks that are Tesseract-specific. -->
